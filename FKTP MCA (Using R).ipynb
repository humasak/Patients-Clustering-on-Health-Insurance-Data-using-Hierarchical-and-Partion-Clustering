# %%
# Import libraries
library(factoextra)
library(FactoMineR)
library(gplots)
# Out:
# Warning message:
# "package 'factoextra' was built under R version 3.6.3"Loading required package: ggplot2
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
# Warning message:
# "package 'FactoMineR' was built under R version 3.6.3"
# Attaching package: 'gplots'
#
# The following object is masked from 'package:stats':
#
#     lowess

# %%
delim = ","  # or is it "\t" ?
dec = "."    # or is it "," ?
myDataFrame <- read.csv("D:/KULIAHHH/TUGAS AKHIR/TA-2/datasampel/FKTP data Binning.csv", header=TRUE, sep=delim, dec=dec, stringsAsFactors=FALSE)

# %%
sapply(myDataFrame, typeof)
# Out:
#                                   X             FKTP.Kepemilikan.Faskes
#                           "integer"                         "character"
#                   FKTP.Jenis.Faskes                    FKTP.Tipe.Faskes
#                         "character"                         "character"
#                FKTP.Tingkat.Layanan                           FKTP.Poli
#                         "character"                         "character"
#                 FKTP.Segmen.Peserta                  FKTP.Status.Pulang
#                         "character"                         "character"
#                       Non.Kapitasi.                            Dirujuk.
#                         "character"                         "character"
#              provinsi.rujukan.sama.              kab.kota.rujukan.sama.
#                         "character"                         "character"
#            FKTP.Tipe.Faskes.Rujukan                 FKTP.Hari.Kunjungan
# ...

# %%
drop <- c('X', 'FKTP.Weekend.', 'FKTP.Quarter')
df = myDataFrame[,!(names(myDataFrame) %in% drop)]

# %%
sapply(df, typeof)
# Out:
#             FKTP.Kepemilikan.Faskes                   FKTP.Jenis.Faskes
#                         "character"                         "character"
#                    FKTP.Tipe.Faskes                FKTP.Tingkat.Layanan
#                         "character"                         "character"
#                           FKTP.Poli                 FKTP.Segmen.Peserta
#                         "character"                         "character"
#                  FKTP.Status.Pulang                       Non.Kapitasi.
#                         "character"                         "character"
#                            Dirujuk.              provinsi.rujukan.sama.
#                         "character"                         "character"
#              kab.kota.rujukan.sama.            FKTP.Tipe.Faskes.Rujukan
#                         "character"                         "character"
#                 FKTP.Hari.Kunjungan                 Kelas.Rawat.Peserta
# ...

# %%
df1 = df[0:1000000,]

# %%
df1
# Out:
#    Hasil.Rujukan.FKTP. FKRTL.Kepemilikan.Faskes  FKRTL.Jenis.Faskes
# 1  No                  PEMERINTAH KABUPATEN/KOTA RUMAH SAKIT
# 2  No                  VERTIKAL/PUSAT            RUMAH SAKIT
# 3  No                  VERTIKAL/PUSAT            RUMAH SAKIT
# 4  No                  SWASTA                    RUMAH SAKIT
# 5  No                  PEMERINTAH KABUPATEN/KOTA RUMAH SAKIT
# 6  No                  SWASTA                    RUMAH SAKIT
# 7  No                  PEMERINTAH KABUPATEN/KOTA RUMAH SAKIT
# 8  No                  PEMERINTAH KABUPATEN/KOTA RUMAH SAKIT
# 9  No                  PEMERINTAH KABUPATEN/KOTA RUMAH SAKIT
# 10 No                  PEMERINTAH KABUPATEN/KOTA RUMAH SAKIT
#    FKRTL.Tipe.Faskes       FKRTL.Tingkat.Layanan     FKRTL.Segmen.Peserta
# 1  RS KELAS C              RAWAT INAP TINGKAT LANJUT PBI APBN
# 2  KHUSUS KANKER ONKOLOGI  RAWAT INAP TINGKAT LANJUT PPU
# 3  RS KELAS A              RAWAT INAP TINGKAT LANJUT PBPU
# ...

# %%
MCA(df1, ncp = 5, graph = FALSE)
# Out:
# **Results of the Multiple Correspondence Analysis (MCA)**
# The analysis was performed on 1000000 individuals, described by 19 variables
# *The results are available in the following objects:
#
#    name              description
# 1  "$eig"            "eigenvalues"
# 2  "$var"            "results for the variables"
# 3  "$var$coord"      "coord. of the categories"
# 4  "$var$cos2"       "cos2 for the categories"
# 5  "$var$contrib"    "contributions of the categories"
# 6  "$var$v.test"     "v-test for the categories"
# 7  "$ind"            "results for the individuals"
# 8  "$ind$coord"      "coord. for the individuals"
# 9  "$ind$cos2"       "cos2 for the individuals"
# 10 "$ind$contrib"    "contributions of the individuals"
# 11 "$call"           "intermediate results"
# 12 "$call$marge.col" "weights of columns"
# 13 "$call$marge.li"  "weights of rows"

# %%
res.mca <- MCA(df1, graph = FALSE)

# %%
print(res.mca)
# Out:
# **Results of the Multiple Correspondence Analysis (MCA)**
# The analysis was performed on 1000000 individuals, described by 19 variables
# *The results are available in the following objects:
#
#    name              description
# 1  "$eig"            "eigenvalues"
# 2  "$var"            "results for the variables"
# 3  "$var$coord"      "coord. of the categories"
# 4  "$var$cos2"       "cos2 for the categories"
# 5  "$var$contrib"    "contributions of the categories"
# 6  "$var$v.test"     "v-test for the categories"
# 7  "$ind"            "results for the individuals"
# 8  "$ind$coord"      "coord. for the individuals"
# 9  "$ind$cos2"       "cos2 for the individuals"
# 10 "$ind$contrib"    "contributions of the individuals"
# 11 "$call"           "intermediate results"
# 12 "$call$marge.col" "weights of columns"
# 13 "$call$marge.li"  "weights of rows"

# %%
library("factoextra")
eig.val <- get_eigenvalue(res.mca)
eig.val
# Out:
#        eigenvalue   variance.percent cumulative.variance.percent
# Dim.1  0.23468510   5.945356          5.945356
# Dim.2  0.14719857   3.729030          9.674386
# Dim.3  0.13271320   3.362068         13.036454
# Dim.4  0.13086456   3.315236         16.351689
# Dim.5  0.11921859   3.020204         19.371894
# Dim.6  0.10741036   2.721062         22.092956
# Dim.7  0.08988822   2.277168         24.370124
# Dim.8  0.08055381   2.040697         26.410821
# Dim.9  0.06626319   1.678667         28.089488
# Dim.10 0.06184897   1.566841         29.656329
# Dim.11 0.06093134   1.543594         31.199923
# Dim.12 0.05914050   1.498226         32.698149
# Dim.13 0.05678054   1.438440         34.136589
# Dim.14 0.05633331   1.427111         35.563700
# Dim.15 0.05545975   1.404980         36.968680
# Dim.16 0.05519878   1.398369         38.367049
# Dim.17 0.05459990   1.383197         39.750247
# Dim.18 0.05418001   1.372560         41.122807
# Dim.19 0.05407831   1.369984         42.492791
# ...

# %%
fviz_screeplot(res.mca, addlabels = TRUE, ylim = c(0, 45))
# Out:
# plot without title

# %%
var <- get_mca_var(res.mca)
var
# Out:
# Multiple Correspondence Analysis Results for variables
# ...
#   Name       Description
# 1 "$coord"   "Coordinates for categories"
# 2 "$cos2"    "Cos2 for categories"
# 3 "$contrib" "contributions of categories"

# %%
library("factoextra")
eig.val <- get_eigenvalue(res.mca)
eig.val
# Out:
#        eigenvalue   variance.percent cumulative.variance.percent
# Dim.1  0.23468510   5.945356          5.945356
# Dim.2  0.14719857   3.729030          9.674386
# Dim.3  0.13271320   3.362068         13.036454
# Dim.4  0.13086456   3.315236         16.351689
# Dim.5  0.11921859   3.020204         19.371894
# Dim.6  0.10741036   2.721062         22.092956
# Dim.7  0.08988822   2.277168         24.370124
# Dim.8  0.08055381   2.040697         26.410821
# Dim.9  0.06626319   1.678667         28.089488
# Dim.10 0.06184897   1.566841         29.656329
# Dim.11 0.06093134   1.543594         31.199923
# Dim.12 0.05914050   1.498226         32.698149
# Dim.13 0.05678054   1.438440         34.136589
# Dim.14 0.05633331   1.427111         35.563700
# Dim.15 0.05545975   1.404980         36.968680
# Dim.16 0.05519878   1.398369         38.367049
# Dim.17 0.05459990   1.383197         39.750247
# Dim.18 0.05418001   1.372560         41.122807
# Dim.19 0.05407831   1.369984         42.492791
# ...

# %%
fviz_screeplot(res.mca, addlabels = TRUE, ylim = c(0, 45))
# Out:
# plot without title
